# %%
pip install ast2json

# %%
import ast
from ast2json import ast2json
import json

# %%
tree = ast.parse(open('test_function.py').read())
ast.dump(tree)
# Out:
# "Module(body=[FunctionDef(name='_interceptdot', args=arguments(args=[arg(arg='w', annotation=None), arg(arg='X', annotation=None), arg(arg='y', annotation=None)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Expr(value=Str(s='\\n  Computes  y∗np . dot (X, w).\\n  It takes into consideration whether  the  intercept  should  be  fit.\\n  Parameters\\n  −−−−−−−−−−\\n  w : ndarray ,  ndarray ,  shape  ( n_features , )  or  ( n_features +  1 , )\\n    Coefficient  vector .\\n  [ . . . ]\\n\\n  ')), Assign(targets=[Name(id='c', ctx=Store())], value=Num(n=0)), If(test=Compare(left=Attribute(value=Name(id='w', ctx=Load()), attr='size', ctx=Load()), ops=[Eq()], comparators=[BinOp(left=Subscript(value=Attribute(value=Name(id='X', ctx=Load()), attr='shape', ctx=Load()), slice=Index(value=Num(n=1)), ctx=Load()), op=Add(), right=Num(n=1))]), body=[Assign(targets=[Name(id='c', ctx=Store())], value=Subscript(value=Name(id='w', ctx=Load()), slice=Index(value=UnaryOp(op
# ...

# %%
ast = ast2json(ast.parse(open('test_function.py').read()))
print(json.dumps(ast, indent=4))
# Out:
# {
#     "_type": "Module",
#     "body": [
#         {
#             "_type": "FunctionDef",
#             "args": {
#                 "_type": "arguments",
#                 "args": [
#                     {
#                         "_type": "arg",
#                         "annotation": null,
#                         "arg": "w",
#                         "col_offset": 19,
#                         "lineno": 1
#                     },
#                     {
#                         "_type": "arg",
#                         "annotation": null,
#                         "arg": "X",
#                         "col_offset": 22,
#                         "lineno": 1
#                     },
#                     {
#                         "_type": "arg",
#                         "annotation": null,
#                         "arg": "y",
#                         "col_offset": 25,
#                         "lineno": 1
#                     }
#                 ],
# ...
